# %%
import lightkurve as lk
import matplotlib.pyplot as plt
import os

# %%
lc = lk.search_lightcurvefile('trappist-1')[0].download().PDCSAP_FLUX

# %%
lc.scatter()
plt.savefig(os.path.join(os.pardir, 'figures/sample.pdf'))
